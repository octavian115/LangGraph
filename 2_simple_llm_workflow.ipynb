# %%
from langgraph.graph import StateGraph,  START, END
from langchain_openai import ChatOpenAI
from typing import TypedDict
from dotenv import load_dotenv

# %%
load_dotenv()
# Out:
# True

# %%
model = ChatOpenAI()

# %%
#create a state
class LLMState(TypedDict):

    question : str
    answer :  str

# %%
def llm_qa(state: LLMState) -> LLMState:

    #extract question from state
    question = state['question']

    #form a prompt
    prompt = f"Answer the following question {question}"

    #ask lllm
    answer = model.invoke(prompt).content

    #update state
    state['answer'] = answer

    return state

# %%
# Create our graph
graph = StateGraph(LLMState)

#add nodes
graph.add_node('llm_qa', llm_qa)

#add edges
graph.add_edge(START, 'llm_qa')
graph.add_edge('llm_qa', END)

workflow = graph.compile()

# %%
#execute the graph
initial_state = {'question': 'how far is the moon from the earth?'}

final_state = workflow.invoke(initial_state)

print(final_state['answer'])
# Out:
# The average distance from the moon to Earth is about 238,855 miles (384,400 kilometers).

# %%
model.invoke('How far is moon from the Earth?').content
# Out:
# 'The average distance from the Earth to the Moon is about 384,400 kilometers (238,855 miles). However, this distance varies as the Moon follows its elliptical orbit around the Earth.'
